# %% [markdown]
# # **رسم فيبوناشي 4 سنوات**

# %%
#@title  اضغط علي علامة التشغيل
import yfinance as yf
import matplotlib.pyplot as plt

# Fetching stock data from Yahoo Finance
ticker_symbol = input("Enter the ticker symbol: ")

# Check if the ticker symbol is a number
if ticker_symbol.isdigit():
    ticker_with_prefix = ticker_symbol + ".SR"
else:
    ticker_with_prefix = ticker_symbol

stock = yf.Ticker(ticker_with_prefix)

######################
# Fetch additional financial data for the ticker
ticker_info = stock.info
ticker_id = ticker_info['symbol'][:-3]
ticker_name = ticker_info['shortName']
ticker_names_arabic = {
            "2030":"ﻲﻓﺎﺼﻤﻟﺍ",
            "2222":"ﺔﻳﺩﻮﻌﺴﻟﺍ ﻮﻜﻣﺍﺭﺃ",
            "2380":"ﻎﺑﺍﺭ ﻭﺮﺘﺑ",
            "2381":"ﺔﻴﺑﺮﻌﻟﺍ ﺮﻔﺤﻟﺍ",
            "2382":"ﺲﻳﺩﺃ",
            "4030":"*ﻱﺮﺤﺒﻟﺍ",
            "4200":"ﺲﻳﺭﺪﻟﺍ",
            "1201":"ﻦﻳﻮﻜﺗ",
            "1202":"ﻮﻜﺒﻣ",
            "1210":"ﻱﺁ ﻲﺳ ﻲﺑ",
            "1211":"ﻥﺩﺎﻌﻣ",
            "1301":"ﻙﻼﺳﺃ",
            "1304":"ﺪﻳﺪﺤﻠﻟ ﺔﻣﺎﻤﻴﻟﺍ",
            "1320":"ﺔﻳﺩﻮﻌﺴﻟﺍ ﺐﻴﺑﺎﻧﺃ",
            "1321":"ﻕﺮﺸﻟﺍ ﺐﻴﺑﺎﻧﺃ",
            "1322":"ﻙﺎﻣﺃ",
            "2001":"ﻝﻮﻧﺎﻤﻴﻛ",
            "2010":"ﻚﺑﺎﺳ",
            "2020":"ﺔﻴﻋﺍﺭﺰﻟﺍ ﺕﺎﻳﺬﻐﻤﻠﻟ ﻚﺑﺎﺳ",
            "2060":"ﻊﻴﻨﺼﺘﻟﺍ",
            "2090":"ﻮﻜﺴﺒﺟ",
            "2150":"ﺝﺎﺟﺯ",
            "2170":"ﻦﻴﺠﻠﻟﺍ",
            "2180":"ﻮﻜﺒﻴﻓ",
            "2200":"ﺐﻴﺑﺎﻧﺃ",
            "2210":"ﺕﺎﻳﻭﺎﻤﻴﻜﻠﻟ ﺀﺎﻤﻧ",
            "2220":"ﺔﻴﻧﺪﻌﻣ",
            "2223":"ﻒﻳﺮﺑﻮﻟ",
            "2240":"ﺔﻋﺎﻨﺼﻠﻟ ﻞﻣﺍﺰﻟﺍ",
            "2250":"ﺔﻳﺩﻮﻌﺴﻟﺍ ﺔﻋﻮﻤﺠﻤﻟﺍ",
            "2290":"ﺏﺎﺴﻨﻳ",
            "2300":"ﻕﺭﻮﻟﺍ ﺔﻋﺎﻨﺻ",
            "2310":"ﺔﻴﻤﻟﺎﻌﻟﺍ ﻢﻴﻜﺒﺳ",
            "2330":"ﺔﻣﺪﻘﺘﻤﻟﺍ",
            "2350":"ﺔﻳﺩﻮﻌﺴﻟﺍ ﻥﺎﻴﻛ",
            "2360":"ﺔﻳﺭﺎﺨﻔﻟﺍ",
            "3001":"ﻞﺋﺎﺣ ﺖﻨﻤﺳﺃ",
            "3002":"ﻥﺍﺮﺠﻧ ﺖﻨﻤﺳﺃ",
            "3003":"ﺔﻨﻳﺪﻤﻟﺍ ﺖﻨﻤﺳﺃ",
            "3004":"ﺔﻴﻟﺎﻤﺸﻟﺍ ﺖﻨﻤﺳﺃ",
            "3005":"ﻯﺮﻘﻟﺍ ﻡﺍ ﺖﻨﻤﺳﺃ",
            "3007":"ﺔﺣﺍﻮﻟﺍ",
            "3008":"ﻱﺮﻴﺜﻜﻟﺍ",
            "3010":"ﺔﻴﺑﺮﻌﻟﺍ ﺖﻨﻤﺳﺃ",
            "3020":"ﺔﻣﺎﻤﻴﻟﺍ ﺖﻨﻤﺳﺃ",
            "3030":"ﺔﻳﺩﻮﻌﺴﻟﺍ ﺖﻨﻤﺳﺃ",
            "3040":"ﻢﻴﺼﻘﻟﺍ ﺖﻨﻤﺳﺃ",
            "3050":"ﺏﻮﻨﺠﻟﺍ ﺖﻨﻤﺳﺃ",
            "3060":"ﻊﺒﻨﻳ ﺖﻨﻤﺳﺃ",
            "3080":"ﺔﻴﻗﺮﺸﻟﺍ ﺖﻨﻤﺳﺃ",
            "3090":"ﻙﻮﺒﺗ ﺖﻨﻤﺳﺃ",
            "3091":"ﻑﻮﺠﻟﺍ ﺖﻨﻤﺳﺃ",
            "3092":"ﺽﺎﻳﺮﻟﺍ ﺖﻨﻤﺳﺃ",
            "9513":"ﻲﻨﻃﻭ ﺪﻳﺪﺣ",
            "9514":"ﻝﻮﻗﺎﻨﻟﺍ",
            "9523":"ﻒﻳﺎﻓ ﺏﻭﺮﺟ",
            "9539":"ﻢﻴﺳﺎﻗﺃ",
            "9548":"ﻮﻜﻴﺑﺍ",
            "9552":"ﺔﻳﺩﻮﻌﺴﻟﺍ ﺔﻤﻗ",
            "9553":"ﻥﻼﻣ",
            "9563":"ﺀﺎﻨﺑ",
            "9565":"ﺭﺎﻴﻌﻣ",
            "9566":"ﺔﻳﺮﻴﺠﻟﺍ ﺕﺎﻋﺎﻨﺼﻟﺍ",
            "9575":"ﻦﻳﺍﺰﻳﺩ ﻞﺑﺭﺎﻣ",
            "9576":"ﻕﺭﻮﻟﺍ ﻝﺰﻨﻣ",
            "9580":"ﺔﻋﺎﻨﺼﻠﻟ ﺪﺷﺍﺮﻟﺍ",
            "9583":"ﻦﻳﺪﻌﺘﻠﻟ ﺓﺪﺤﺘﻤﻟﺍ",
            "9588":"ﺽﺎﻳﺮﻟﺍ ﺪﻳﺪﺣ",
            "1212":"ﺔﻴﻋﺎﻨﺼﻟﺍ ﺍﺮﺘﺳﺃ",
            "1214":"ﺮﻛﺎﺷ",
            "1302":"ﻥﺍﻮﺑ",
            "1303":"ﺔﻴﺋﺎﺑﺮﻬﻜﻟﺍ ﺕﺎﻋﺎﻨﺼﻟﺍ",
            "2040":"ﻱﺩﻮﻌﺴﻟﺍ ﻑﺰﺨﻟﺍ",
            "2110":"ﺔﻳﺩﻮﻌﺴﻟﺍ ﺕﻼﺑﺎﻜﻟﺍ",
            "2160":"ﺖﻴﺘﻧﺎﻴﻣﺃ",
            "2320":"ﻦﻴﻄﺑﺎﺒﻟﺍ",
            "2370":"ﻚﺴﻣ",
            "4110":"ﻚﺗﺎﺑ",
            "4140":"ﺕﺍﺭﺩﺎﺻ",
            "4141":"ﻥﺍﺮﻤﻌﻟﺍ",
            "4142":"ﺽﺎﻳﺮﻟﺍ ﺕﻼﺑﺎﻛ",
            "9510":"ﻖﻳﻮﺴﺘﻟﺍﻭ ﺀﺎﻨﺒﻠﻟ ﺔﻴﻨﻃﻮﻟﺍ",
            "9525":"ﺔﻴﻋﺎﻨﺼﻟﺍ ﻞﺋﺎﺳﻮﻟﺍ",
            "9528":"ﺯﺎﺟ",
            "9529":"ﻡﻭﺅﺭ",
            "9531":"ﺝﺎﺟﺰﻠﻟ ﻥﺎﻜﻴﺒﻌﻟﺍ",
            "9533":"ﻲﻟﻵﺍ ﺰﻛﺮﻤﻟﺍ",
            "9542":"ﺮﻴﻛ",
            "9547":"ﻲﺳﺍﻭﺭ",
            "9560":"ﺎﺟﻭ",
            "9568":"ﺭﺎﻴﻣ",
            "9569":"ﻒﻴﻨﻣ ﻝﺁ",
            "9578":"ﺲﻠﻃﺃ ﺪﻋﺎﺼﻣ",
            "1831":"ﺓﺭﺎﻬﻣ",
            "1832":"ﺭﺪﺻ",
            "1833":"ﺩﺭﺍﻮﻤﻟﺍ",
            "4270":"ﻒﻴﻠﻐﺗﻭ ﺔﻋﺎﺒﻃ",
            "6004":"ﻥﻮﻳﺮﺗﺎﻛ",
            "9540":"ﺮﻳﻭﺪﺗ",
            "9545":"ﺔﻴﻟﻭﺪﻟﺍ",
            "9570":"ﺔﻳﻮﻤﻨﺘﻟﺍ ﻡﺎﺗ",
            "9581":"ﻒﻳﻻ ﻦﻴﻠﻛ",
            "2190":"ﺔﻀﺑﺎﻘﻟﺍ ﻮﻜﺴﻴﺳ",
            "4031":"ﺔﻴﺿﺭﻷﺍ ﺕﺎﻣﺪﺨﻟﺍ",
            "4040":"ﻮﻜﺘﺑﺎﺳ",
            "4260":"ﺔﻳﺩﻮﻌﺴﻟﺍ ﺖﺟﺪﺑ",
            "4261":"ﺐﻳﺫ",
            "4262":"ﻲﻣﻮﻟ",
            "4263":"ﻝﺎﺳ",
            "9571":"ﻪﻟﻭﺎﻨﻣ",
            "9577":"ﺔﺒﻛﺮﻤﻟﺍ ﺭﺍﺩ",
            "9584":"ﻝﺎﻳﺭ",
            "1213":"ﺞﻴﺴﻧ",
            "2130":"ﻕﺪﺻ",
            "2340":"ﻒﻴﻄﻠﻟﺍﺪﺒﻌﻟﺍ",
            "4011":"ﻱﺩﺭﻭﺯﻻ",
            "4012":"ﻞﻴﺻﻷﺍ",
            "4180":"ﻲﺤﻴﺘﻓ ﺔﻋﻮﻤﺠﻣ",
            "1810":"ﺍﺮﻴﺳ",
            "1820":"ﺮﻴﻜﺤﻟﺍ ﺔﻋﻮﻤﺠﻣ",
            "1830":"ﺔﻗﺎﻴﻠﻟﺍ ﺖﻗﻭ",
            "4170":"ﺲﻤﺷ",
            "4290":"ﺐﻳﺭﺪﺘﻠﻟ ﺞﻴﻠﺨﻟﺍ",
            "4291":"ﻢﻴﻠﻌﺘﻠﻟ ﺔﻴﻨﻃﻮﻟﺍ",
            "4292":"ﺀﺎﻄﻋ",
            "6002":"ﺔﻳﺬﻏﻸﻟ ﻲﻓﺮﻫ",
            "6012":"ﻥﺍﺪﻳﺭ",
            "6013":"ﺔﻴﺋﺍﺬﻐﻟﺍ ﺔﻳﺮﻳﻮﻄﺘﻟﺍ",
            "6014":"ﺭﺎﻣﻵﺍ",
            "6015":"ﺎﻧﺎﻜﻳﺮﻣﺃ",
            "9520":"ﺭﺯﺰﻳﺍﺮﻏﺮﺑ",
            "9526":"ﺰﻫﺎﺟ",
            "9541":"ﻢﻠﻌﺘﻟﺍ ﺔﻴﻤﻳﺩﺎﻛﺃ",
            "9562":"ﺔﻤﻌﻃﻷﺍ ﺔﺑﺍﻮﺑ",
            "9567":"ﻥﺎﻄﻠﺴﻟﺍ ﺀﺍﺬﻏ",
            "9590":"ﺡﺎﻣﺭﺃ",
            "4070":"ﺔﻣﺎﻬﺗ",
            "4071":"ﺔﻴﺑﺮﻌﻟﺍ",
            "4072":"ﻲﺳ ﻲﺑ ﻡﺇ ﺔﻋﻮﻤﺠﻣ",
            "4210":"ﻡﻼﻋﻹﺍﻭ ﺙﺎﺤﺑﻷﺍ",
            "4003":"ﺍﺮﺘﺴﻛﺇ",
            "4008":"ﻮﻛﺎﺳ",
            "4050":"ﻮﻜﺳﺎﺳ",
            "4051":"ﻢﻴﻈﻋﺎﺑ",
            "4190":"ﺮﻳﺮﺟ",
            "4191":"ﻲﻄﻌﻣ ﻮﺑﺃ",
            "4192":"ﻱﺮﻴﻟﺎﻏ ﻒﻴﺴﻟﺍ",
            "4240":"ﻞﻴﺘﻳﺭ ﻲﻣﻮﻨﻴﺳ",
            "9522":"ﺏﻮﺳﺎﺤﻟﺍ",
            "9537":"ﺔﻴﻟﻭﺪﻟﺍ ﺝﺍﻮﻣﺃ",
            "9551":"ﺔﻓﺮﻌﻤﻟﺍ ﺝﺮﺑ",
            "9589":"ﺩﺎﻓ",
            "4001":"ﻢﻴﺜﻌﻟﺍ ﻉ ﻕﺍﻮﺳﺃ",
            "4006":"ﺔﻋﺭﺰﻤﻟﺍ ﻕﺍﻮﺳﺃ",
            "4061":"ﺔﻀﺑﺎﻘﻟﺍ ﻡﺎﻌﻧﺃ",
            "4160":"ﺭﺎﻤﺛ",
            "4161":"ﺩﻭﺍﺩ ﻦﺑ",
            "4162":"ﻢﺠﻨﻤﻟﺍ",
            "4163":"ﺀﺍﻭﺪﻟﺍ",
            "4164":"ﻱﺪﻬﻨﻟﺍ",
            "9549":"ﺔﻴﺋﺍﺬﻐﻟﺍ ﻦﻴﻄﺑﺎﺒﻟﺍ",
            "9592":"ﺔﻴﺒﻄﻟﺍ ﻊﻤﺘﺠﻤﻟﺍ",
            "2050":"ﻻﻮﻓﺎﺻ ﺔﻋﻮﻤﺠﻣ",
            "2100":"ﺓﺮﻓﻭ",
            "2270":"ﻮﻜﻓﺍﺪﺳ",
            "2280":"ﻲﻋﺍﺮﻤﻟﺍ",
            "2281":"ﺔﻴﻤﻨﺗ",
            "2282":"ﻲﻘﻧ",
            "2283":"ﻰﻟﻭﻷﺍ ﻦﺣﺎﻄﻤﻟﺍ",
            "4080":"ﺔﻀﺑﺎﻘﻟﺍ ﺩﺎﻨﺳ",
            "6001":"ﻥﺍﻮﺧﺇ ﻲﻧﺍﻮﻠﺣ",
            "6010":"ﻙﺩﺎﻧ",
            "6020":"ﻮﻛﺎﺟ",
            "6040":"ﺔﻴﻋﺍﺭﺰﻟﺍ ﻙﻮﺒﺗ",
            "6050":"ﻙﺎﻤﺳﻷﺍ",
            "6060":"ﺔﻴﻤﻨﺘﻠﻟ ﺔﻴﻗﺮﺸﻟﺍ",
            "6070":"ﻑﻮﺠﻟﺍ",
            "6090":"ﻮﻛﺩﺍﺯﺎﺟ",
            "9515":"ﺵﺎﻓ ﺶﻓ",
            "9532":"ﻑﻮﺠﻟﺍ ﻩﺎﻴﻣ",
            "9536":"ﻮﻜﻳﺩﺎﻓ",
            "9555":"ﺮﻴﺨﻟﺍ ﻦﻴﻟ",
            "9556":"ﺫﻮﻔﻧ",
            "9559":"ﻱﺪﻠﺑ",
            "9564":"ﺀﺍﺬﻐﻟﺍ ﻕﺎﻓﺁ",
            "9517":"ﺔﻋﺎﻨﺼﻠﻟ ﻲﺑﻮﻣ",
            "9579":"ﻲﻛﺬﻟﺍ ﺭﻮﺨﺒﻟﺍ",
            "2140":"ﻥﺎﻳﺃ",
            "2230":"ﺔﻴﺋﺎﻴﻤﻴﻜﻟﺍ",
            "4002":"ﺓﺎﺳﺍﻮﻤﻟﺍ",
            "4004":"ﺔﻴﺤﺼﻟﺍ ﻪﻟﺩ",
            "4005":"ﺔﻳﺎﻋﺭ",
            "4007":"ﻱﺩﺎﻤﺤﻟﺍ",
            "4009":"ﺔﻴﺤﺼﻟﺍ ﻲﻧﺎﻤﻟﻷﺍ ﻱﺩﻮﻌﺴﻟﺍ",
            "4013":"ﺐﻴﺒﺤﻟﺍ ﻥﺎﻤﻴﻠﺳ",
            "4014":"ﺕﺍﺪﻌﻤﻟﺍ ﺭﺍﺩ",
            "9518":"ﻲﺒﻄﻟﺍ ﻱﺪﻨﻜﻟﺍ ﺰﻛﺮﻤﻟﺍ",
            "9527":"ﺀﺎﻳ ﻢﻴﻣ ﻒﻟﺃ",
            "9530":"ﺔﻴﺒﻃ",
            "9544":"ﺔﻴﻠﺒﻘﺘﺴﻤﻟﺍ ﺔﻳﺎﻋﺮﻟﺍ",
            "9546":"ﺔﺤﺼﻟﺍ ﻊﺒﻧ",
            "9572":"ﻱﺯﺍﺮﻟﺍ",
            "9574":"ﺲﻜﻳﺪﻴﻣﻭﺮﺑ",
            "9587":"ﺎﻧﻻ",
            "2070":"ﺔﻴﺋﺍﻭﺪﻟﺍ",
            "4015":"ﺎﻣﺭﺎﻓ ﻡﻮﺠﻤﺟ",
            "1010":"ﺽﺎﻳﺮﻟﺍ",
            "1020":"ﺓﺮﻳﺰﺠﻟﺍ",
            "1030":"ﺭﺎﻤﺜﺘﺳﻹﺍ",
            "1050":"ﻲﺴﻧﺮﻔﻟﺍ ﻱﺩﻮﻌﺴﻟﺍ",
            "1060":"ﻝﻭﻷﺍ",
            "1080":"ﻲﺑﺮﻌﻟﺍ",
            "1120":"ﻲﺤﺟﺍﺮﻟﺍ",
            "1140":"ﺩﻼﺒﻟﺍ",
            "1150":"ﺀﺎﻤﻧﻹﺍ",
            "1180":"ﻲﻠﻫﻷﺍ",
            "1111":"ﻝﻭﺍﺪﺗ ﺔﻋﻮﻤﺠﻣ",
            "1182":"ﻙﻼﻣﺃ",
            "1183":"ﻞﻬﺳ",
            "2120":"ﺓﺭﻮﻄﺘﻣ",
            "4081":"ﺕﺎﻔﻳﺎﻨﻟﺍ",
            "4082":"ﺔﻧﺮﻣ",
            "4130":"ﺔﺣﺎﺒﻟﺍ",
            "4280":"ﺔﻜﻠﻤﻤﻟﺍ",
            "9585":"ﺔﻴﻜﻠﻣ",
            "9586":"ﺖﻴﺨﺑﻭ ﻝﻮﺻﺃ",
            "8010":"ﺔﻴﻧﻭﺎﻌﺘﻟﺍ",
            "8012":"ﻞﻓﺎﻜﺗ ﺓﺮﻳﺰﺟ",
            "8020":"ﻦﻴﻣﺄﺘﻠﻟ ﺫﻼﻣ",
            "8030":"ﻦﻴﻣﺄﺘﻠﻟ ﻒﻠﻏﺪﻴﻣ",
            "8040":"ﻑﺇ ﺱﺇ ﺰﻧﺎﻴﻟﺃ",
            "8050":"ﺔﻣﻼﺳ",
            "8060":"ﺀﻻﻭ",
            "8070":"ﻲﺑﺮﻌﻟﺍ ﻉﺭﺪﻟﺍ",
            "8100":"ﻮﻜﻳﺎﺳ",
            "8120":"ﺔﻴﻠﻫﻷﺍ ﺞﻴﻠﺨﻟﺍ ﺩﺎﺤﺗﺇ",
            "8150":"ﺞﻴﺳﺃ",
            "8160":"ﺔﻴﺑﺮﻌﻟﺍ ﻦﻴﻣﺄﺘﻟﺍ",
            "8170":"ﺩﺎﺤﺗﻻﺍ",
            "8180":"ﻦﻴﻣﺄﺘﻠﻟ ﺮﻘﺼﻟﺍ",
            "8190":"ﻦﻴﻣﺄﺘﻠﻟ ﺓﺪﺤﺘﻤﻟﺍ",
            "8200":"ﺔﻳﺩﻮﻌﺴﻟﺍ ﺓﺩﺎﻋﻹﺍ",
            "8210":"ﺔﻴﺑﺮﻌﻟﺍ ﺎﺑﻮﺑ",
            "8230":"ﻲﺤﺟﺍﺮﻟﺍ ﻞﻓﺎﻜﺗ",
            "8240":"ﺐﺸْﺗ",
            "8250":"ﻲﺟ ﻱﺁ ﻲﺟ",
            "8260":"ﺔﻣﺎﻌﻟﺍ ﺔﻴﺠﻴﻠﺨﻟﺍ",
            "8270":"ﻦﻴﻣﺄﺘﻠﻟ ﺝﻭﺮﺑ",
            "8280":"ﺎﻔﻴﻟ",
            "8300":"ﺔﻴﻨﻃﻮﻟﺍ",
            "8310":"ﻦﻴﻣﺄﺘﻠﻟ ﺔﻧﺎﻣﺃ",
            "8311":"ﺔﻳﺎﻨﻋ",
            "7200":"ﺱﺍ ﻱﺁ ﻡﺍ",
            "7201":"ﺏﺮﻌﻟﺍ ﺮﺤﺑ",
            "7202":"ﺰﻨﺷﻮﻠﺳ",
            "7203":"ﻢﻠﻋ",
            "7204":"ﻲﺑﻮﺗ",
            "9524":"ﻚﺘﻜﻳﺁ",
            "9534":"ﻡﺰﻋ",
            "9538":"ﺔﻴﻨﻘﺘﻠﻟ ﺞﻴﺴﻧ",
            "9543":"ﺱﺮﻛﺭﻭ ﺖﻧ",
            "9550":"ﺭﻮﺷ",
            "9557":"ﺕﺍﺭﺍﺩﺇ",
            "9558":"ﻢﻤﻘﻟﺍ",
            "9561":"ﺖﻨﺠﻟﻮﻧ",
            "7010":"ﻲﺳ ﻲﺗ ﺱﺍ",
            "7020":"ﺕﻻﺎﺼﺗﺇ ﺩﺎﺤﺗﺇ",
            "7030":"ﺔﻳﺩﻮﻌﺴﻟﺍ ﻦﻳﺯ",
            "7040":"ﺕﻻﺎﺼﺗﻺﻟ ﺐﻳﺬﻋ",
            "2080":"ﺯﺎﻐﻟﺍ",
            "2081":"ﻒﻳﺮﺨﻟﺍ",
            "2082":"ﺭﻭﺎﺑ ﺍﻮﻛﺃ",
            "2083":"ﻖﻓﺍﺮﻣ",
            "5110":"ﺔﻳﺩﻮﻌﺴﻟﺍ ﺀﺎﺑﺮﻬﻛ",
            "9516":"ﺯﺎﻏ",
            "4330":"ﺖﻳﺭ ﺽﺎﻳﺮﻟﺍ",
            "4331":"ﺖﻳﺭ ﺓﺮﻳﺰﺠﻟﺍ",
            "4332":"ﻦﻴﻣﺮﺤﻟﺍ ﺖﻳﺭ ﻯﻭﺪﺟ",
            "4333":"ﺖﻳﺭ ﻢﻴﻠﻌﺗ",
            "4334":"ﺖﻳﺭ ﺭﺬﻌﻤﻟﺍ",
            "4335":"ﺖﻳﺭ ﺔﻛﺭﺎﺸﻣ",
            "4336":"ﺖﻳﺭ ﺔﻴﻜﻠﻣ",
            "4337":"ﺖﻳﺭ ﺔﻳﺩﻮﻌﺴﻟﺍ ﻮﻜﻴﺳ",
            "4338":"1 ﺖﻳﺭ ﻲﻠﻫﻷﺍ",
            "4339":"ﺖﻳﺭ ﺔﻳﺍﺭﺩ",
            "4340":"ﺖﻳﺭ ﻲﺤﺟﺍﺮﻟﺍ",
            "4342":"ﺔﻳﺩﻮﻌﺴﻟﺍ ﺖﻳﺭ ﻯﻭﺪﺟ",
            "4344":"ﺖﻳﺭ ﻝﺎﺘﻴﺑﺎﻛ ﻮﻛﺪﺳ",
            "4345":"ﺔﺋﺰﺠﺘﻠﻟ ﺖﻳﺭ ﺀﺎﻤﻧﻹﺍ",
            "4346":"ﺖﻳﺭ ﻚﻔﻴﻣ",
            "4347":"ﺖﻳﺭ ﻥﺎﻴﻨﺑ",
            "4348":"ﺖﻳﺭ ﺮﻴﺒﺨﻟﺍ",
            "4349":"ﻲﻗﺪﻨﻔﻟﺍ ﺖﻳﺭ ﺀﺎﻤﻧﻹﺍ",
            "9300":"ﺖﻳﺭ ﺔﺣﺍﻮﻟﺍ",
            "4020":"ﺔﻳﺭﺎﻘﻌﻟﺍ",
            "4090":"*ﺔﺒﻴﻃ",
            "4100":"*ﺔﻜﻣ",
            "4150":"ﺮﻴﻤﻌﺘﻟﺍ",
            "4220":"ﺭﺎﻤﻋﺇ",
            "4230":"ﺮﻤﺣﻷﺍ ﺮﺤﺒﻟﺍ",
            "4250":"*ﺮﻤﻋ ﻞﺒﺟ",
            "4300":"ﻥﺎﻛﺭﻷﺍ ﺭﺍﺩ",
            "4310":"*ﺔﻓﺮﻌﻤﻟﺍ ﺔﻨﻳﺪﻣ",
            "4320":"ﺲﻟﺪﻧﻷﺍ",
            "4321":"ﺯﺮﺘﻨﺳ ﻲﻣﻮﻨﻴﺳ",
            "4322":"ﻝﺎﺗﺭ",
            "4323":"ﻮﻤﺳ",
            "9519":"ﻥﺎﻨﺑ",
            "9521":"ﻲﺑﺍﻭﺮﻟﺍ ﺀﺎﻤﻧﺇ",
            "9535":"ﻥﺪﻟ",
            "9591":"ﻮﻴﻓ",
            "4700":"ﻞﺧﺪﻠﻟ ﺮﻴﺒﺨﻟﺍ",
            "4701":"ﻞﺧﺪﻟﺍﻭ ﻮﻤﻨﻠﻟ ﺮﻴﺒﺨﻟﺍ",
            "9400":"30 ﻦﻴﻘﻳ",
            "9401":"ﺕﺎﻳﻭﺎﻤﻴﻛﻭﺮﺘﺒﻠﻟ ﻦﻴﻘﻳ",
            "9402":"30 ﻲﺗ ﻡﺇ ﻝﻭﻷﺍ",
            "9403":"ﺩﻼﺒﻟﺍ ﻙﻮﻜﺻ",
            "9404":"ﺀﺎﻤﻧﻹﺍ ﻙﻮﻜﺻ",
            "9405":"ﺐﻫﺬﻠﻟ ﺩﻼﺒﻟﺍ",
            "9406":"ﻱﺁ ﻲﺳ ﺱﺇ ﻡﺇ ﺩﻼﺒﻟﺍ",
            "9407":"ﻲﻜﻳﺮﻣﻷﺍ ﻲﻨﻘﺘﻟﺍ ﺩﻼﺒﻟﺍ",
            "9408":"ﻱﺩﻮﻌﺴﻟﺍ ﻮﻤﻨﻠﻟ ﺩﻼﺒﻟﺍ",
}
try:
    ticker_name_arabic = ticker_names_arabic.get(ticker_id, 'N/A')
except KeyError:
    ticker_name_arabic = 'N/A'
######################

history = stock.history(period="4y")

# Extracting the volume data
volume_data = history['Close']

# Setting up the chart size
plt.figure(figsize=(20, 12))

# Plotting the volume profile
plt.plot(volume_data, color='black', label='Close')

# Calculating support and resistance levels
support_level = min(volume_data)
resistance_level = max(volume_data)
diff = resistance_level - support_level
rr = (support_level + resistance_level) / 2

# Fibonacci levels from the bottom (in reverse order)
plt.axhline(y=support_level + 1 * diff, color='blue', linestyle='solid', linewidth=7, label='Top')
plt.axhline(y=support_level + 0.764 * diff, color='blue', linestyle='solid', label='76%-')
plt.axhline(y=support_level + 0.618 * diff, color='blue', linestyle='solid', label='61%-')
plt.axhline(y=support_level + 0.50 * diff, color='blue', linestyle='solid', linewidth=2, label='50%-')
plt.axhline(y=support_level + 0.382 * diff, color='blue', linestyle='solid', label='38%-')
plt.axhline(y=support_level + 0.236 * diff, color='blue', linestyle='solid', label='23%-')
plt.axhline(y=support_level + 0 * diff, color='blue', linestyle='solid', linewidth=7, label='Bottom')

# Fibonacci levels from the top to lowest price between top and close
lowest_price = min(volume_data[volume_data.idxmax():])
diff_lowest = resistance_level - lowest_price
plt.axhline(y=lowest_price + 1 * diff_lowest, color='red', linestyle='--', linewidth=4, label='Top')
plt.axhline(y=lowest_price + 0.764 * diff_lowest, color='red', linestyle='--', label='76%- L')
plt.axhline(y=lowest_price + 0.618 * diff_lowest, color='red', linestyle='--', label='61%- L')
plt.axhline(y=lowest_price + 0.50 * diff_lowest, color='red', linestyle='--', linewidth=3, label='50%- L')
plt.axhline(y=lowest_price + 0.382 * diff_lowest, color='red', linestyle='--', label='38%- L')
plt.axhline(y=lowest_price + 0.236 * diff_lowest, color='red', linestyle='--', label='23%- L')
plt.axhline(y=lowest_price + 0 * diff_lowest, color='red', linestyle='--', linewidth=3, label='Bottom')

# Adding labels and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title(f"{ticker_name_arabic} ﻢﻬﺴﻟ ﺕﺍﻮﻨﺳ 4 ﻲﺷﺎﻧﻮﺒﻴﻓ")
plt.legend()

# Adding ticker name and ticker ID on the chart (bottom right)
#plt.text(0.6, 0.15, f"{ticker_name}", transform=plt.gca().transAxes, fontsize=18, ha='right', va='bottom')
#plt.text(0.6, 0.12, f" {ticker_name_arabic}", transform=plt.gca().transAxes, fontsize=18, ha='right', va='bottom')
#plt.text(0.50, 0.05, f"{ticker_name} \n {ticker_symbol} :ﺰﻣﺮﻟﺍ \n {ticker_name_arabic}", transform=plt.gca().transAxes, fontsize=18, ha='center', va='bottom')
# Adding ticker name and ticker ID on the chart (bottom right)
text = f"{ticker_name} \n {ticker_symbol} :ﺰﻣﺮﻟﺍ \n {ticker_name_arabic}"
bbox_props = dict(boxstyle="round,pad=0.3", fc="white", ec="black", lw=2)
plt.text(0.50, 0.06, text, transform=plt.gca().transAxes, fontsize=18, ha='center', va='bottom', bbox=bbox_props)

text2 = "ﺕﺍﻮﻨﺳ 4 ﻮﺒﻴﻓ ﺀﺎﻗﺭﺰﻟﺍ ﻁﻮﻄﺨﻟﺍ \nﻕﻼﻏﻻﺍ ﻦﻴﺑﻭ ﺎﻬﻨﻴﺑ ﻉﺎﻗ ﻲﻧﺩﺍ ﻲﻟﺍ ﺕﺍﻮﻨﺳ 4 ﺔﻤﻗ ﻦﻣ ﺀﺍﺮﻤﺤﻟﺍ"
bbox_props2 = dict(boxstyle="round,pad=0.3", fc="white", ec="black", lw=2)
plt.text(0.70, 0.90, text2, transform=plt.gca().transAxes, fontsize=18, ha='center', va='bottom', bbox=bbox_props2)

# Displaying the plot
plt.show()
# Out:
# Enter the ticker symbol: 8010
